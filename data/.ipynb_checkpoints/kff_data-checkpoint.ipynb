# %%
# Preliminaries --------------------------------------------------------
if (!require("pacman")) install.packages("pacman")
pacman::p_load(tidyverse, ggplot2, dplyr, lubridate, haven)
# Out:
# Loading required package: pacman

# %%
# Preliminaries --------------------------------------------------------
kff.dat <- read_csv('data/input/raw_data__.csv', skip = 2)
# Out:
# Error: 'data/input/raw_data__.csv' does not exist in current working directory ('/home/ski2983/econ470/a0/work/hwk5/data').
# Traceback:
#
# 1. read_csv("data/input/raw_data__.csv", skip = 2)
# 2. vroom::vroom(file, delim = ",", col_names = col_names, col_types = col_types,
#  .     col_select = {
#  .         {
#  .             col_select
#  .         }
#  .     }, id = id, .name_repair = name_repair, skip = skip, n_max = n_max,
#  .     na = na, quote = quote, comment = comment, skip_empty_rows = skip_empty_rows,
#  .     trim_ws = trim_ws, escape_double = TRUE, escape_backslash = FALSE,
#  .     locale = locale, guess_max = guess_max, show_col_types = show_col_types,
#  .     progress = progress, altrep = lazy, num_threads = num_threads)
# 3. vroom_(file, delim = delim %||% col_types$delim, col_names = col_names,
#  .     col_types = col_types, id = id, skip = skip, col_select = col_select,
#  .     name_repair = .name_repair, na = na, quote = quote, trim_ws = trim_ws,
# ...

# %%
# Clean KFF data --------------------------------------------------------
kff.final <- kff.dat %>%
  mutate(
    expanded = (`Status of Medicaid Expansion Decision` == "Adopted"),
    date_adopted = mdy(`Expansion Implementation Date`)
  ) %>%
  select(State = Location, expanded, date_adopted)
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `date_adopted = mdy(`Expansion Implementation Date`)`.
# Caused by warning:
# !  10 failed to parse.”

# %%
write_rds(kff.final, 'medicaid-kff.rds')
